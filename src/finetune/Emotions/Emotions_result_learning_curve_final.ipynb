# %% [markdown]
# # **Mount my Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---

# %% [markdown]
# # **Script Start**

# %%
import numpy as np
import json
import os
import csv #[Hyosun]
import pandas as pd #[Hyosun]
import random       #[Hyosun]

# [Hyosun] confusion matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
# [/Hyosun] confusion matrix

# %%
def get_immediate_files(a_dir):
    return [name for name in os.listdir(a_dir) if os.path.isfile(os.path.join(a_dir, name))]

# %% [markdown]
# # **Emotions**

# %%
# dataset downloaded from https://zenodo.org/record/3819968
# please change it to your Emotions dataset path
# [Hyosun] current path: ./src/prep_data/Emotions [/Hyosun]
event_path = './data/Emotions_audio_16k/'
#[Hyosun] use 7 labels
emotions_path = './data/Emotions_audio_16k/'
labels_arr = ['Angry', 'Happy', 'Sad', 'Neutral', 'Fearful', 'Disgusted', 'Surprised']

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /content/drive/My Drive/hssast/src/finetune/Emotions

# %%
os.chdir('/content/drive/MyDrive/hssast/src/finetune')
print(os.getcwd())
cur_dir = os.getcwd()
# Out:
# /content/drive/MyDrive/hssast/src/finetune

# %%
dataset_folder = '/Emotions'

# %%
os.chdir(cur_dir+dataset_folder) #+'/exp/') #+ result_dir+'/')

# %%
cur_dir = os.getcwd()
print(cur_dir)
# Out:
# /content/drive/MyDrive/hssast/src/finetune/Emotions

# %% [markdown]
# - **[]SSAST**

# %%
dir_ssast = '2024-01-15/11:55:32AM-test01-emotions-comp_fusion-False-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[]-pooling-mean-comp_fusion_mlp0-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# ## **mlp2**

# %% [markdown]
# - **[]mean[mlp2]**

# %%
dir_mlp2_mean = '2024-01-15/15:36:16PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-mean-comp_fusion_mlp2-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]mean+max[mlp2]**

# %%
dir_mlp2_meanmax = '2024-01-15/19:26:58PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-mean_max-comp_fusion_mlp2-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]max[mlp2]**

# %%
dir_mlp2_max = '2024-01-16/09:10:18AM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-max-comp_fusion_mlp2-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]max+max[mlp2]**

# %%
dir_mlp2_maxmax = '2024-01-16/20:55:40PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-max_max-comp_fusion_mlp2-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %%
#ssast
result_dir = dir_ssast

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_ssast = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_ssast = np.array(results_ssast, dtype=float)
    print("results_ssast[:,0]: \n", results_ssast[:,0])
    print("results_ssast[:,0].size: ", results_ssast[:,0].size)
    print("results_ssast[:,2]: \n", results_ssast[:,2])
    print("results_ssast[:,2].size: ", results_ssast[:,2].size)
    print("results_ssast[:,3]: \n", results_ssast[:,3])
    print("results_ssast[:,3].size: ", results_ssast[:,3].size)
    print("results_ssast.shape: ", results_ssast.shape)
# Out:
# results_ssast[:,0]:
#  [0.52321498 0.6004682  0.66367538 0.69879048 0.67303941 0.70425283
#  0.72922357 0.7541943  0.73039407 0.75341397 0.77331252 0.75965665
#  0.76550917 0.76433867 0.765119   0.76902068 0.77292236 0.77448303
#  0.78579789 0.77838471 0.78072571 0.77955521 0.7772142  0.78423722
#  0.77994538 0.78423722 0.77994538 0.7881389  0.78423722 0.78501756
#  0.78540773 0.78150605 0.78072571 0.78384705 0.77955521 0.78384705
#  0.78423722 0.78345689 0.78540773 0.78540773 0.78540773 0.78735856
#  0.78657823 0.78657823 0.78618806]
# results_ssast[:,0].size:  45
# results_ssast[:,2]:
#  [0.22182616 0.22657892 0.22877251 0.22961921 0.23143005 0.23190478
#  0.23163046 0.23188008 0.23290935 0.23224568 0.23227634 0.23254089
#  0.23242848 0.23226739 0.23224568 0.23206288 0.23206288 0.23188008
#  0.23219632 0.23233708 0.23233708 0.23197845 0.23215428 0.23224568
#  0.23197148 0.23206288 0.23224568 0.23225264 0.23245382 0.23224568
# ...

# %%
#mean
result_dir = dir_mlp2_mean

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp2_mean = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp2_mean = np.array(results_mlp2_mean, dtype=float)
    print("results_mlp2_mean[:,0]: \n", results_mlp2_mean[:,0])
    print("results_mlp2_mean[:,0].size: ", results_mlp2_mean[:,0].size)
    print("results_mlp2_mean[:,2]: \n", results_mlp2_mean[:,2])
    print("results_mlp2_mean[:,2].size: ", results_mlp2_mean[:,2].size)
    print("results_mlp2_mean[:,3]: \n", results_mlp2_mean[:,3])
    print("results_mlp2_mean[:,3].size: ", results_mlp2_mean[:,3].size)
    print("results_mlp2_mean.shape: ", results_mlp2_mean.shape)
# Out:
# results_mlp2_mean[:,0]:
#  [0.54155287 0.61334374 0.60593055 0.69020679 0.68006243 0.68552478
#  0.73156457 0.73858759 0.74483028 0.74483028 0.75575497 0.74483028
#  0.75458447 0.75146313 0.74951229 0.76199766 0.77565353 0.75770581
#  0.7760437  0.76824034 0.77565353 0.77019118 0.77448303 0.78033554
#  0.77331252 0.77916504 0.7772142  0.77370269 0.77565353 0.77253219
#  0.77838471 0.77370269 0.77370269 0.77331252 0.77448303 0.77526336
#  0.7760437  0.77682403 0.77643387 0.77643387 0.77682403 0.77643387
#  0.77682403 0.77760437 0.77799454]
# results_mlp2_mean[:,0].size:  45
# results_mlp2_mean[:,2]:
#  [0.21902426 0.22568845 0.22740152 0.2291381  0.23124029 0.23117265
#  0.23216125 0.23209085 0.23261128 0.23225264 0.23178868 0.23197148
#  0.23215428 0.23224568 0.23215428 0.23215428 0.23245335 0.23224568
#  0.23325107 0.23261128 0.23242848 0.23270268 0.23299858 0.23288548
#  0.23279408 0.23300221 0.23279408 0.23279408 0.23263667 0.23272368
# ...

# %%
#mean+max
result_dir = dir_mlp2_meanmax

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp2_meanmax = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp2_meanmax = np.array(results_mlp2_meanmax, dtype=float)
    print("results_mlp2_meanmax[:,0]: \n", results_mlp2_meanmax[:,0])
    print("results_mlp2_meanmax[:,0].size: ", results_mlp2_meanmax[:,0].size)
    print("results_mlp2_meanmax[:,2]: \n", results_mlp2_meanmax[:,2])
    print("results_mlp2_meanmax[:,2].size: ", results_mlp2_meanmax[:,2].size)
    print("results_mlp2_meanmax[:,3]: \n", results_mlp2_meanmax[:,3])
    print("results_mlp2_meanmax[:,3].size: ", results_mlp2_meanmax[:,3].size)
    print("results_mlp2_meanmax.shape: ", results_mlp2_meanmax.shape)
# Out:
# results_mlp2_meanmax[:,0]:
#  [0.50097542 0.61841592 0.66601639 0.68630511 0.69176746 0.70893484
#  0.72376122 0.68669528 0.75107296 0.73858759 0.73936793 0.7662895
#  0.76433867 0.76589934 0.76785018 0.77136169 0.78150605 0.77526336
#  0.77136169 0.77409286 0.77448303 0.78306672 0.78423722 0.78267655
#  0.78735856 0.78345689 0.78345689 0.78462739 0.78774873 0.78345689
#  0.78345689 0.78267655 0.78345689 0.78189622 0.78384705 0.78111588
#  0.78150605 0.78189622 0.78267655 0.78267655 0.78384705 0.78306672
#  0.78618806 0.78657823 0.78540773]
# results_mlp2_meanmax[:,0].size:  45
# results_mlp2_meanmax[:,2]:
#  [0.21863415 0.22667032 0.22895531 0.23005906 0.23169729 0.23097305
#  0.23163093 0.2321781  0.23235809 0.23233708 0.23288548 0.23242848
#  0.23233708 0.23224568 0.23233708 0.23242848 0.23263656 0.23270268
#  0.23242848 0.23270964 0.23233708 0.2322709  0.23206288 0.23215428
#  0.23242848 0.23206288 0.23233708 0.23233708 0.2322709  0.23242848
# ...

# %%
#max
result_dir = dir_mlp2_max

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp2_max = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp2_max = np.array(results_mlp2_max, dtype=float)
    print("results_mlp2_max[:,0]: \n", results_mlp2_max[:,0])
    print("results_mlp2_max[:,0].size: ", results_mlp2_max[:,0].size)
    print("results_mlp2_max[:,2]: \n", results_mlp2_max[:,2])
    print("results_mlp2_max[:,2].size: ", results_mlp2_max[:,2].size)
    print("results_mlp2_max[:,3]: \n", results_mlp2_max[:,3])
    print("results_mlp2_max[:,3].size: ", results_mlp2_max[:,3].size)
    print("results_mlp2_max.shape: ", results_mlp2_max.shape)
# Out:
# results_mlp2_max[:,0]:
#  [0.51502146 0.58798283 0.62660944 0.66718689 0.70425283 0.69957082
#  0.73780726 0.72337105 0.73741709 0.7530238  0.7518533  0.75029263
#  0.765119   0.77019118 0.7760437  0.77058135 0.77331252 0.77565353
#  0.77994538 0.77838471 0.77994538 0.78501756 0.78423722 0.78774873
#  0.78189622 0.78852907 0.78657823 0.78540773 0.78540773 0.7881389
#  0.78774873 0.78852907 0.7893094  0.7893094  0.78891924 0.79165041
#  0.79126024 0.7893094  0.79047991 0.79087007 0.79165041 0.78969957
#  0.79165041 0.79008974 0.79087007]
# results_mlp2_max[:,0].size:  45
# results_mlp2_max[:,2]:
#  [0.22136916 0.22776711 0.22776711 0.22998545 0.23126492 0.23170425
#  0.23215428 0.23206288 0.23261128 0.23270964 0.23252684 0.23251988
#  0.23288548 0.23281936 0.23288548 0.23288548 0.23251988 0.23297688
#  0.23270268 0.23263305 0.23315967 0.23279408 0.23291046 0.23297688
#  0.23306828 0.23288548 0.23299782 0.23291046 0.23279408 0.23297688
# ...

# %%
#max+max
result_dir = dir_mlp2_maxmax

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp2_maxmax = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp2_maxmax = np.array(results_mlp2_maxmax, dtype=float)
    print("results_mlp2_maxmax[:,0]: \n", results_mlp2_maxmax[:,0])
    print("results_mlp2_maxmax[:,0].size: ", results_mlp2_maxmax[:,0].size)
    print("results_mlp2_maxmax[:,2]: \n", results_mlp2_maxmax[:,2])
    print("results_mlp2_maxmax[:,2].size: ", results_mlp2_maxmax[:,2].size)
    print("results_mlp2_maxmax[:,3]: \n", results_mlp2_maxmax[:,3])
    print("results_mlp2_maxmax[:,3].size: ", results_mlp2_maxmax[:,3].size)
    print("results_mlp2_maxmax.shape: ", results_mlp2_maxmax.shape)
# Out:
# results_mlp2_maxmax[:,0]:
#  [0.50409676 0.60515021 0.65626219 0.70269216 0.71010535 0.72454155
#  0.72532189 0.68669528 0.76667967 0.765119   0.77058135 0.76941085
#  0.77370269 0.78111588 0.76941085 0.77682403 0.77175185 0.77955521
#  0.765119   0.78111588 0.78423722 0.78345689 0.78072571 0.78501756
#  0.7772142  0.78228638 0.78618806 0.78501756 0.78033554 0.78267655
#  0.78072571 0.78306672 0.78111588 0.78111588 0.78072571 0.78072571
#  0.78072571 0.78267655 0.78150605 0.77994538 0.78150605 0.78267655
#  0.78306672 0.78345689 0.78306672]
# results_mlp2_maxmax[:,0].size:  45
# results_mlp2_maxmax[:,2]:
#  [0.22036377 0.22650836 0.22785851 0.23005906 0.23089833 0.23114889
#  0.23133169 0.23225962 0.23245019 0.23251988 0.23297688 0.23254089
#  0.23215428 0.23251988 0.23242848 0.23243544 0.23251988 0.23251988
#  0.23272801 0.23242848 0.23242848 0.23243544 0.23251988 0.23236078
#  0.23236242 0.23234404 0.23225264 0.23206288 0.23224568 0.23235809
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **mlp4**

# %% [markdown]
# - **[]mean[mlp4]**

# %%
dir_mlp4_mean = '2024-01-15/15:50:13PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-mean-comp_fusion_mlp4-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]mean+max[mlp4]**

# %%
dir_mlp4_meanmax = '2024-01-15/19:33:12PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-mean_max-comp_fusion_mlp4-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]max[mlp4]**

# %%
dir_mlp4_max = '2024-01-16/21:09:14PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-max-comp_fusion_mlp4-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]max+max[mlp4]**

# %%
dir_mlp4_maxmax = '2024-01-15/12:11:01PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-max_max-comp_fusion_mlp4-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %%
#ssast
result_dir = dir_ssast

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_ssast = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_ssast = np.array(results_ssast, dtype=float)
    print("results_ssast[:,0]: \n", results_ssast[:,0])
    print("results_ssast[:,0].size: ", results_ssast[:,0].size)
    print("results_ssast[:,2]: \n", results_ssast[:,2])
    print("results_ssast[:,2].size: ", results_ssast[:,2].size)
    print("results_ssast[:,3]: \n", results_ssast[:,3])
    print("results_ssast[:,3].size: ", results_ssast[:,3].size)
    print("results_ssast.shape: ", results_ssast.shape)
# Out:
# results_ssast[:,0]:
#  [0.52321498 0.6004682  0.66367538 0.69879048 0.67303941 0.70425283
#  0.72922357 0.7541943  0.73039407 0.75341397 0.77331252 0.75965665
#  0.76550917 0.76433867 0.765119   0.76902068 0.77292236 0.77448303
#  0.78579789 0.77838471 0.78072571 0.77955521 0.7772142  0.78423722
#  0.77994538 0.78423722 0.77994538 0.7881389  0.78423722 0.78501756
#  0.78540773 0.78150605 0.78072571 0.78384705 0.77955521 0.78384705
#  0.78423722 0.78345689 0.78540773 0.78540773 0.78540773 0.78735856
#  0.78657823 0.78657823 0.78618806]
# results_ssast[:,0].size:  45
# results_ssast[:,2]:
#  [0.22182616 0.22657892 0.22877251 0.22961921 0.23143005 0.23190478
#  0.23163046 0.23188008 0.23290935 0.23224568 0.23227634 0.23254089
#  0.23242848 0.23226739 0.23224568 0.23206288 0.23206288 0.23188008
#  0.23219632 0.23233708 0.23233708 0.23197845 0.23215428 0.23224568
#  0.23197148 0.23206288 0.23224568 0.23225264 0.23245382 0.23224568
# ...

# %%
#mean
result_dir = dir_mlp4_mean

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp4_mean = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp4_mean = np.array(results_mlp4_mean, dtype=float)
    print("results_mlp4_mean[:,0]: \n", results_mlp4_mean[:,0])
    print("results_mlp4_mean[:,0].size: ", results_mlp4_mean[:,0].size)
    print("results_mlp4_mean[:,2]: \n", results_mlp4_mean[:,2])
    print("results_mlp4_mean[:,2].size: ", results_mlp4_mean[:,2].size)
    print("results_mlp4_mean[:,3]: \n", results_mlp4_mean[:,3])
    print("results_mlp4_mean[:,3].size: ", results_mlp4_mean[:,3].size)
    print("results_mlp4_mean.shape: ", results_mlp4_mean.shape)
# Out:
# results_mlp4_mean[:,0]:
#  [0.53531018 0.60671089 0.63285213 0.66445572 0.70932501 0.67538041
#  0.71283652 0.7409286  0.7276629  0.76316816 0.76043699 0.74756145
#  0.7772142  0.75029263 0.77058135 0.77760437 0.7662895  0.77370269
#  0.78228638 0.7760437  0.78501756 0.77370269 0.77877487 0.7760437
#  0.77955521 0.79126024 0.78618806 0.78189622 0.77838471 0.78033554
#  0.78111588 0.78657823 0.78189622 0.78852907 0.78852907 0.7893094
#  0.78345689 0.78423722 0.78306672 0.78150605 0.78228638 0.78111588
#  0.78189622 0.78306672 0.78345689]
# results_mlp4_mean[:,0].size:  45
# results_mlp4_mean[:,2]:
#  [0.222123   0.22685312 0.22861294 0.22989066 0.2295951  0.22989083
#  0.23133169 0.23160589 0.23188008 0.23169729 0.23251988 0.23224568
#  0.23206288 0.23272363 0.23242848 0.23251988 0.23288548 0.23270964
#  0.23261128 0.23270268 0.23318501 0.23261128 0.23261128 0.23261128
#  0.23272433 0.23281941 0.23275171 0.23270268 0.23270268 0.23281912
# ...

# %%
#mean+max
result_dir = dir_mlp4_meanmax

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp4_meanmax = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp4_meanmax = np.array(results_mlp4_meanmax, dtype=float)
    print("results_mlp4_meanmax[:,0]: \n", results_mlp4_meanmax[:,0])
    print("results_mlp4_meanmax[:,0].size: ", results_mlp4_meanmax[:,0].size)
    print("results_mlp4_meanmax[:,2]: \n", results_mlp4_meanmax[:,2])
    print("results_mlp4_meanmax[:,2].size: ", results_mlp4_meanmax[:,2].size)
    print("results_mlp4_meanmax[:,3]: \n", results_mlp4_meanmax[:,3])
    print("results_mlp4_meanmax[:,3].size: ", results_mlp4_meanmax[:,3].size)
    print("results_mlp4_meanmax.shape: ", results_mlp4_meanmax.shape)
# Out:
# results_mlp4_meanmax[:,0]:
#  [0.54350371 0.60358954 0.60085837 0.69020679 0.69059696 0.71556769
#  0.69059696 0.7288334  0.75146313 0.76121732 0.76433867 0.7760437
#  0.77136169 0.77409286 0.78072571 0.77292236 0.78345689 0.77331252
#  0.77877487 0.77448303 0.77409286 0.78462739 0.78423722 0.78501756
#  0.78891924 0.79087007 0.7893094  0.78345689 0.78735856 0.79126024
#  0.78969957 0.78891924 0.78852907 0.78969957 0.78852907 0.78852907
#  0.78852907 0.78735856 0.7869684  0.7881389  0.7869684  0.78852907
#  0.78735856 0.7881389  0.7869684 ]
# results_mlp4_meanmax[:,0].size:  45
# results_mlp4_meanmax[:,2]:
#  [0.22251142 0.2242095  0.22831551 0.23067238 0.22897631 0.23163093
#  0.23126399 0.23179565 0.23188008 0.23226669 0.23227757 0.23197148
#  0.23244949 0.23254516 0.23251988 0.23270268 0.23242848 0.23242848
#  0.23279408 0.23315967 0.23245007 0.23270268 0.23288548 0.23251988
#  0.23242848 0.23233708 0.23251988 0.23270268 0.23251988 0.23254475
# ...

# %%
#max
result_dir = dir_mlp4_max

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp4_max = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp4_max = np.array(results_mlp4_max, dtype=float)
    print("results_mlp4_max[:,0]: \n", results_mlp4_max[:,0])
    print("results_mlp4_max[:,0].size: ", results_mlp4_max[:,0].size)
    print("results_mlp4_max[:,2]: \n", results_mlp4_max[:,2])
    print("results_mlp4_max[:,2].size: ", results_mlp4_max[:,2].size)
    print("results_mlp4_max[:,3]: \n", results_mlp4_max[:,3])
    print("results_mlp4_max[:,3].size: ", results_mlp4_max[:,3].size)
    print("results_mlp4_max.shape: ", results_mlp4_max.shape)
# Out:
# results_mlp4_max[:,0]:
#  [0.51111978 0.59032384 0.66367538 0.69761998 0.68123293 0.72610222
#  0.72415139 0.74287944 0.74678112 0.75809598 0.76043699 0.75731565
#  0.7518533  0.76863051 0.78111588 0.78384705 0.77799454 0.77409286
#  0.77253219 0.77409286 0.78072571 0.78306672 0.77565353 0.78228638
#  0.77838471 0.78150605 0.78267655 0.78423722 0.78579789 0.78228638
#  0.78150605 0.78150605 0.78267655 0.78462739 0.78267655 0.78111588
#  0.78267655 0.78384705 0.78306672 0.78501756 0.78462739 0.78150605
#  0.78189622 0.78150605 0.78306672]
# results_mlp4_max[:,0].size:  45
# results_mlp4_max[:,2]:
#  [0.22191756 0.22557353 0.22904671 0.2293209  0.23078329 0.23133169
#  0.23110366 0.23133169 0.23144409 0.23133169 0.23151449 0.23151449
#  0.23215428 0.23151449 0.23199249 0.23188008 0.23133169 0.23178868
#  0.23161285 0.23169729 0.23153965 0.2315572  0.23136375 0.23191151
#  0.23160589 0.23178868 0.23188008 0.23188705 0.23179565 0.23181256
# ...

# %%
#max+max
result_dir = dir_mlp4_maxmax

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp4_maxmax = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp4_maxmax = np.array(results_mlp4_maxmax, dtype=float)
    print("results_mlp4_maxmax[:,0]: \n", results_mlp4_maxmax[:,0])
    print("results_mlp4_maxmax[:,0].size: ", results_mlp4_maxmax[:,0].size)
    print("results_mlp4_maxmax[:,2]: \n", results_mlp4_maxmax[:,2])
    print("results_mlp4_maxmax[:,2].size: ", results_mlp4_maxmax[:,2].size)
    print("results_mlp4_maxmax[:,3]: \n", results_mlp4_maxmax[:,3])
    print("results_mlp4_maxmax[:,3].size: ", results_mlp4_maxmax[:,3].size)
    print("results_mlp4_maxmax.shape: ", results_mlp4_maxmax.shape)
# Out:
# results_mlp4_maxmax[:,0]:
#  [0.50799844 0.60983223 0.6827936  0.68513461 0.67225907 0.70386266
#  0.68318377 0.72688256 0.73858759 0.77175185 0.76589934 0.76902068
#  0.76980101 0.76863051 0.77331252 0.77292236 0.77955521 0.78150605
#  0.77526336 0.78228638 0.7772142  0.77448303 0.78384705 0.77526336
#  0.77565353 0.77799454 0.77916504 0.78891924 0.78657823 0.78540773
#  0.78579789 0.77994538 0.78657823 0.78618806 0.78267655 0.78189622
#  0.78423722 0.78267655 0.78345689 0.78540773 0.78423722 0.78423722
#  0.78423722 0.78423722 0.78423722]
# results_mlp4_maxmax[:,0].size:  45
# results_mlp4_maxmax[:,2]:
#  [0.22173476 0.22676869 0.22817545 0.23050909 0.22886391 0.23133169
#  0.23169729 0.23224568 0.23153976 0.23236236 0.23261128 0.23251988
#  0.23197148 0.23206288 0.23242848 0.23254527 0.23242848 0.23245388
#  0.23224568 0.23216125 0.23217529 0.23215428 0.23217962 0.23224568
#  0.23233708 0.23251988 0.23252684 0.23251988 0.23246072 0.23235856
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **mlp6**

# %% [markdown]
# - **[]mean[mlp6]**

# %%
dir_mlp6_mean = '2024-01-15/19:19:48PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-mean-comp_fusion_mlp6-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]mean+max[mlp6]**

# %%
dir_mlp6_meanmax = '2024-01-16/08:29:54AM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-mean_max-comp_fusion_mlp6-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]max[mlp6]**

# %%
dir_mlp6_max = '2024-01-16/15:03:47PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-max-comp_fusion_mlp6-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %% [markdown]
# - **[]max+max[mlp6]**

# %%
dir_mlp6_maxmax = '2024-01-16/15:15:29PM-test01-emotions-comp_fusion-True-comp_fusion_method-use_all_patch-comp_fusion_multi_layer-[4,11]-pooling-max_max-comp_fusion_mlp6-loss-CE-f10-16-t10-16-b48-lr1e-4-ft_avgtok-base--SSAST-Base-Patch-400-1x-noiseTrue'

# %%
#ssast
result_dir = dir_ssast

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_ssast = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_ssast = np.array(results_ssast, dtype=float)
    print("results_ssast[:,0]: \n", results_ssast[:,0])
    print("results_ssast[:,0].size: ", results_ssast[:,0].size)
    print("results_ssast[:,2]: \n", results_ssast[:,2])
    print("results_ssast[:,2].size: ", results_ssast[:,2].size)
    print("results_ssast[:,3]: \n", results_ssast[:,3])
    print("results_ssast[:,3].size: ", results_ssast[:,3].size)
    print("results_ssast.shape: ", results_ssast.shape)
# Out:
# results_ssast[:,0]:
#  [0.52321498 0.6004682  0.66367538 0.69879048 0.67303941 0.70425283
#  0.72922357 0.7541943  0.73039407 0.75341397 0.77331252 0.75965665
#  0.76550917 0.76433867 0.765119   0.76902068 0.77292236 0.77448303
#  0.78579789 0.77838471 0.78072571 0.77955521 0.7772142  0.78423722
#  0.77994538 0.78423722 0.77994538 0.7881389  0.78423722 0.78501756
#  0.78540773 0.78150605 0.78072571 0.78384705 0.77955521 0.78384705
#  0.78423722 0.78345689 0.78540773 0.78540773 0.78540773 0.78735856
#  0.78657823 0.78657823 0.78618806]
# results_ssast[:,0].size:  45
# results_ssast[:,2]:
#  [0.22182616 0.22657892 0.22877251 0.22961921 0.23143005 0.23190478
#  0.23163046 0.23188008 0.23290935 0.23224568 0.23227634 0.23254089
#  0.23242848 0.23226739 0.23224568 0.23206288 0.23206288 0.23188008
#  0.23219632 0.23233708 0.23233708 0.23197845 0.23215428 0.23224568
#  0.23197148 0.23206288 0.23224568 0.23225264 0.23245382 0.23224568
# ...

# %%
#mean
result_dir = dir_mlp6_mean

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp6_mean = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp6_mean = np.array(results_mlp6_mean, dtype=float)
    print("results_mlp6_mean[:,0]: \n", results_mlp6_mean[:,0])
    print("results_mlp6_mean[:,0].size: ", results_mlp6_mean[:,0].size)
    print("results_mlp6_mean[:,2]: \n", results_mlp6_mean[:,2])
    print("results_mlp6_mean[:,2].size: ", results_mlp6_mean[:,2].size)
    print("results_mlp6_mean[:,3]: \n", results_mlp6_mean[:,3])
    print("results_mlp6_mean[:,3].size: ", results_mlp6_mean[:,3].size)
    print("results_mlp6_mean.shape: ", results_mlp6_mean.shape)
# Out:
# results_mlp6_mean[:,0]:
#  [0.36168552 0.49863441 0.55676941 0.59812719 0.65236052 0.65548186
#  0.6839641  0.70854467 0.72493172 0.71088568 0.72415139 0.71985954
#  0.73468591 0.72610222 0.74404994 0.74131877 0.74483028 0.74951229
#  0.74795162 0.75380414 0.74834179 0.74522044 0.75107296 0.75575497
#  0.74717128 0.74522044 0.75224346 0.7530238  0.7518533  0.7541943
#  0.7518533  0.75575497 0.75614514 0.75653531 0.75692548 0.75653531
#  0.75848615 0.75692548 0.75809598 0.75926648 0.75809598 0.76043699
#  0.75848615 0.75848615 0.76004682]
# results_mlp6_mean[:,0].size:  45
# results_mlp6_mean[:,2]:
#  [0.20775066 0.21899278 0.22411114 0.22465954 0.22759128 0.22858971
#  0.2292295  0.2303263  0.23024186 0.23162689 0.23087469 0.23105749
#  0.23096609 0.23124029 0.23144831 0.23106445 0.23114889 0.23117417
#  0.23151449 0.23124029 0.23124029 0.23133169 0.23126563 0.23114889
#  0.23151449 0.23126463 0.23117329 0.23136013 0.23142309 0.23114889
# ...

# %%
#mean+max
result_dir = dir_mlp6_meanmax

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp6_meanmax = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp6_meanmax = np.array(results_mlp6_meanmax, dtype=float)
    print("results_mlp6_meanmax[:,0]: \n", results_mlp6_meanmax[:,0])
    print("results_mlp6_meanmax[:,0].size: ", results_mlp6_meanmax[:,0].size)
    print("results_mlp6_meanmax[:,2]: \n", results_mlp6_meanmax[:,2])
    print("results_mlp6_meanmax[:,2].size: ", results_mlp6_meanmax[:,2].size)
    print("results_mlp6_meanmax[:,3]: \n", results_mlp6_meanmax[:,3])
    print("results_mlp6_meanmax[:,3].size: ", results_mlp6_meanmax[:,3].size)
    print("results_mlp6_meanmax.shape: ", results_mlp6_meanmax.shape)
# Out:
# results_mlp6_meanmax[:,0]:
#  [0.48809988 0.61334374 0.63324229 0.65665236 0.6827936  0.70542333
#  0.72142021 0.71322669 0.71322669 0.74678112 0.75341397 0.76121732
#  0.75614514 0.7748732  0.77097152 0.77526336 0.76902068 0.78267655
#  0.76863051 0.77409286 0.77916504 0.77955521 0.78345689 0.77370269
#  0.78189622 0.78189622 0.78423722 0.78072571 0.79008974 0.78579789
#  0.78384705 0.78423722 0.78891924 0.78852907 0.78774873 0.78891924
#  0.78306672 0.79087007 0.79047991 0.79243075 0.79165041 0.79243075
#  0.79360125 0.79165041 0.79204058]
# results_mlp6_meanmax[:,0].size:  45
# results_mlp6_meanmax[:,2]:
#  [0.21789599 0.22557353 0.22694452 0.22868111 0.22979914 0.23124029
#  0.23105749 0.23133169 0.23188008 0.23170425 0.23188008 0.23206288
#  0.23169729 0.23215428 0.23169729 0.23251988 0.23216125 0.2319953
#  0.23190109 0.23160589 0.23190109 0.23169729 0.23114889 0.23151449
#  0.23197148 0.23188008 0.23160589 0.23163058 0.23142309 0.23151449
# ...

# %%
#max
result_dir = dir_mlp6_max

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp6_max = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp6_max = np.array(results_mlp6_max, dtype=float)
    print("results_mlp6_max[:,0]: \n", results_mlp6_max[:,0])
    print("results_mlp6_max[:,0].size: ", results_mlp6_max[:,0].size)
    print("results_mlp6_max[:,2]: \n", results_mlp6_max[:,2])
    print("results_mlp6_max[:,2].size: ", results_mlp6_max[:,2].size)
    print("results_mlp6_max[:,3]: \n", results_mlp6_max[:,3])
    print("results_mlp6_max[:,3].size: ", results_mlp6_max[:,3].size)
    print("results_mlp6_max.shape: ", results_mlp6_max.shape)
# Out:
# results_mlp6_max[:,0]:
#  [0.50916894 0.61763558 0.65470152 0.6839641  0.67460008 0.70971518
#  0.73078424 0.74248927 0.74287944 0.76277799 0.76589934 0.76355833
#  0.76238783 0.7893094  0.78423722 0.77916504 0.78345689 0.78462739
#  0.79126024 0.78072571 0.79516192 0.79126024 0.78891924 0.78540773
#  0.78774873 0.78657823 0.7893094  0.7869684  0.78735856 0.79126024
#  0.78891924 0.79047991 0.79360125 0.79555209 0.79204058 0.79282091
#  0.79438158 0.79360125 0.79438158 0.79438158 0.79594226 0.79360125
#  0.79360125 0.79360125 0.79360125]
# results_mlp6_max[:,0].size:  45
# results_mlp6_max[:,2]:
#  [0.21698199 0.22302131 0.22777408 0.22904671 0.2293209  0.23060049
#  0.23096609 0.23115585 0.23235102 0.23242848 0.23281936 0.23251988
#  0.23242848 0.23251988 0.23188008 0.23261824 0.23254089 0.23233708
#  0.23288548 0.23215428 0.23233708 0.23242848 0.23233708 0.23224568
#  0.23251988 0.23233708 0.23224568 0.23234404 0.23242848 0.23242848
# ...

# %%
#max+max
result_dir = dir_mlp6_maxmax

# %%
import csv
if os.path.exists('./exp/'+ result_dir+'/result.csv') == True:

    # [Hyosun] load acc (ind=0 at result.csv)
    results_mlp6_maxmax = np.loadtxt('./exp/'+ result_dir+'/result.csv', delimiter=',', dtype='str')
    results_mlp6_maxmax = np.array(results_mlp6_maxmax, dtype=float)
    print("results_mlp6_maxmax[:,0]: \n", results_mlp6_maxmax[:,0])
    print("results_mlp6_maxmax[:,0].size: ", results_mlp6_maxmax[:,0].size)
    print("results_mlp6_maxmax[:,2]: \n", results_mlp6_maxmax[:,2])
    print("results_mlp6_maxmax[:,2].size: ", results_mlp6_maxmax[:,2].size)
    print("results_mlp6_maxmax[:,3]: \n", results_mlp6_maxmax[:,3])
    print("results_mlp6_maxmax[:,3].size: ", results_mlp6_maxmax[:,3].size)
    print("results_mlp6_maxmax.shape: ", results_mlp6_maxmax.shape)
# Out:
# results_mlp6_maxmax[:,0]:
#  [0.48536871 0.65197035 0.62504877 0.6925478  0.68240343 0.70152165
#  0.72532189 0.75536481 0.73078424 0.74404994 0.75146313 0.75575497
#  0.7639485  0.75731565 0.77877487 0.76824034 0.77097152 0.76550917
#  0.77175185 0.76589934 0.77292236 0.78150605 0.78033554 0.7760437
#  0.77409286 0.7748732  0.77643387 0.77877487 0.77838471 0.77994538
#  0.78267655 0.7760437  0.78111588 0.78228638 0.77955521 0.78072571
#  0.78345689 0.78150605 0.78423722 0.78462739 0.78345689 0.78267655
#  0.78150605 0.78267655 0.78384705]
# results_mlp6_maxmax[:,0].size:  45
# results_mlp6_maxmax[:,2]:
#  [0.22228316 0.22753493 0.22969346 0.2292295  0.2299607  0.23078329
#  0.23142309 0.23188008 0.23188008 0.2320867  0.23178868 0.23245382
#  0.23251988 0.23206288 0.23215428 0.23206288 0.23169729 0.23224568
#  0.23224568 0.23151449 0.23188008 0.23197148 0.23151449 0.23199945
#  0.23226669 0.23206288 0.23206288 0.23215428 0.23226956 0.23215428
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Plot**

# %% [markdown]
# ### **create the label description dictionary**

# %%
# [Hyosun: create the label description dictionary]
if os.path.exists('./data/event_04s_class_labels_indices.csv') == True:
    label_set = np.loadtxt('./data/event_04s_class_labels_indices.csv', delimiter=',', dtype='str')
    label_map = {}
    for i in range(1, len(label_set)):
        print("[Hyosun] label_set[i][0]: ", label_set[i][0])
        print("[Hyosun] label_set[i][2]: ", label_set[i][2])
        label_map[(label_set[i][2])] = label_set[i][0]
    print(label_map)
    print("[Hyosun] create the label description dictionary: using event_04s_class_labels_indices.csv finished!!")
#[/Hyosun: create the label description dictionary]

# %% [markdown]
# ### **Learning Curve**

# %% [markdown]
# ### **Accuracy**

# %%
fig, axs = plt.subplots(3,1,figsize=(6, 14))
# fig.suptitle('[Emotions] Accuracy with various number of layers at mlp_head') #, fontdict={'fontsize': 10}, loc='center', )


#mlp_head with 2 layers
axs[0].plot([i for i in range(1, results_ssast[:,0].size+1)],        results_ssast[:,0], 'o-', markersize=3, label='SSAST')
axs[0].plot([i for i in range(1, results_mlp2_mean[:,0].size+1)],    results_mlp2_mean[:,0], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[0].plot([i for i in range(1, results_mlp2_meanmax[:,0].size+1)], results_mlp2_meanmax[:,0], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[0].plot([i for i in range(1, results_mlp2_max[:,0].size+1)],     results_mlp2_max[:,0], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[0].plot([i for i in range(1, results_mlp2_maxmax[:,0].size+1)],  results_mlp2_maxmax[:,0], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[0].legend(loc=(0.37, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[0].set_xticks(np.arange(0, 50, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[0].set_yticks(np.arange(0.4, np.max(results_mlp2_maxmax[:,0])+0.05, 0.05)) #, rotation=45)
axs[0].set_xlim(0, 47)
axs[0].set_ylim(0.60, 0.81)
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('Accuracy with mlp_head 2 layers')
axs[0].grid(True, linestyle='-')
# axs[0].set_title('Accuracy with mlp_head 2 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 4 layers
axs[1].plot([i for i in range(1, results_ssast[:,0].size+1)],        results_ssast[:,0], 'o-', markersize=3, label='SSAST')
axs[1].plot([i for i in range(1, results_mlp4_mean[:,0].size+1)],    results_mlp4_mean[:,0], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[1].plot([i for i in range(1, results_mlp4_meanmax[:,0].size+1)], results_mlp4_meanmax[:,0], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[1].plot([i for i in range(1, results_mlp4_max[:,0].size+1)],     results_mlp4_max[:,0], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[1].plot([i for i in range(1, results_mlp4_maxmax[:,0].size+1)],  results_mlp4_maxmax[:,0], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[1].legend(loc=(0.37, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[1].set_xticks(np.arange(0, 50, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[1].set_yticks(np.arange(0.4, np.max(results_mlp4_maxmax[:,0])+0.05, 0.05)) #, rotation=45)
axs[1].set_xlim(0, 47)
axs[1].set_ylim(0.60, 0.81)
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('Accuracy with mlp_head 4 layers')
axs[1].grid(True, linestyle='-')
# axs[1].set_title('Accuracy with mlp_head 4 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 6 layers
axs[2].plot([i for i in range(1, results_ssast[:,0].size+1)],        results_ssast[:,0], 'o-', markersize=3, label='SSAST')
axs[2].plot([i for i in range(1, results_mlp6_mean[:,0].size+1)],    results_mlp6_mean[:,0], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[2].plot([i for i in range(1, results_mlp6_meanmax[:,0].size+1)], results_mlp6_meanmax[:,0], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[2].plot([i for i in range(1, results_mlp6_max[:,0].size+1)],     results_mlp6_max[:,0], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[2].plot([i for i in range(1, results_mlp6_maxmax[:,0].size+1)],  results_mlp6_maxmax[:,0], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[2].legend(loc=(0.37, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[2].set_xticks(np.arange(0, 50, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[2].set_yticks(np.arange(0.4, np.max(results_mlp6_maxmax[:,0])+0.05, 0.05)) #, rotation=45)
axs[2].set_xlim(0, 47)
axs[2].set_ylim(0.60, 0.81)
axs[2].set_xlabel('epoch')
axs[2].set_ylabel('Accuracy with mlp_head 6 layers')
axs[2].grid(True, linestyle='-')
# axs[2].set_title('Accuracy with mlp_head 6 layers\n', fontdict={'fontsize': 10}, loc='center', )


fig.savefig('Emotions_Accuracy_num-layers_mlphead.png',dpi=300)

# %% [markdown]
# ### **subplots_LOSS**

# %%
fig, axs = plt.subplots(3,1,figsize=(6, 16))
# fig.suptitle('[Emotions] Loss with various number of layers at mlp_head') #, fontdict={'fontsize': 10}, loc='center', )


#mlp_head with 2 layers
axs[0].plot([i for i in range(1, results_ssast[:,6].size+1)],        results_ssast[:,6], 'o-', markersize=3, label='SSAST')
axs[0].plot([i for i in range(1, results_mlp2_mean[:,6].size+1)],    results_mlp2_mean[:,6], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[0].plot([i for i in range(1, results_mlp2_meanmax[:,6].size+1)], results_mlp2_meanmax[:,6], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[0].plot([i for i in range(1, results_mlp2_max[:,6].size+1)],     results_mlp2_max[:,6], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[0].plot([i for i in range(1, results_mlp2_maxmax[:,6].size+1)],  results_mlp2_maxmax[:,6], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[0].legend(loc=(0.40, 0.70), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[0].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
# axs[0].set_yticks(np.arange(0.9, np.max(results_mlp2_maxmax[:,6])+0.05, 0.005)) #, rotation=45)
# axs[0].set_ylim(1.65, 2.00)
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('Loss with mlp_head 2 layers')
axs[0].grid(True, linestyle='-')
# axs[0].set_title('Accuracy with mlp_head 2 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 4 layers
axs[1].plot([i for i in range(1, results_ssast[:,6].size+1)],        results_ssast[:,6], 'o-', markersize=3, label='SSAST')
axs[1].plot([i for i in range(1, results_mlp4_mean[:,6].size+1)],    results_mlp4_mean[:,6], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[1].plot([i for i in range(1, results_mlp4_meanmax[:,6].size+1)], results_mlp4_meanmax[:,6], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[1].plot([i for i in range(1, results_mlp4_max[:,6].size+1)],     results_mlp4_max[:,6], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[1].plot([i for i in range(1, results_mlp4_maxmax[:,6].size+1)],  results_mlp4_maxmax[:,6], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[1].legend(loc=(0.40, 0.70), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[1].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
# axs[1].set_yticks(np.arange(0.9, np.max(results_mlp4_maxmax[:,6])+0.05, 0.005)) #, rotation=45)
# axs[1].set_ylim(1.65, 2.00)
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('Loss with mlp_head 4 layers')
axs[1].grid(True, linestyle='-')
# axs[1].set_title('Accuracy with mlp_head 4 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 6 layers
axs[2].plot([i for i in range(1, results_ssast[:,6].size+1)],        results_ssast[:,6], 'o-', markersize=3, label='SSAST')
axs[2].plot([i for i in range(1, results_mlp6_mean[:,6].size+1)],    results_mlp6_mean[:,6], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[2].plot([i for i in range(1, results_mlp6_meanmax[:,6].size+1)], results_mlp6_meanmax[:,6], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[2].plot([i for i in range(1, results_mlp6_max[:,6].size+1)],     results_mlp6_max[:,6], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[2].plot([i for i in range(1, results_mlp6_maxmax[:,6].size+1)],  results_mlp6_maxmax[:,6], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[2].legend(loc=(0.40, 0.70), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[2].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
# axs[2].set_yticks(np.arange(0.9, np.max(results_mlp6_maxmax[:,6])+0.05, 0.005)) #, rotation=45)
# axs[2].set_ylim(1.65, 2.00)
axs[2].set_xlabel('epoch')
axs[2].set_ylabel('Loss with mlp_head 6 layers')
axs[2].grid(True, linestyle='-')
# axs[2].set_title('Accuracy with mlp_head 6 layers\n', fontdict={'fontsize': 10}, loc='center', )


fig.savefig('Emotions_Loss_num-layers_mlphead.png',dpi=300)

# %% [markdown]
# ### **subplots_AP**

# %%
fig, axs = plt.subplots(3,1,figsize=(6, 16))
# fig.suptitle('[Emotions] Average Precision with various number of layers at mlp_head') #, fontdict={'fontsize': 10}, loc='center', )


#mlp_head with 2 layers
axs[0].plot([i for i in range(1, results_ssast[:,2].size+1)],        results_ssast[:,2], 'o-', markersize=3, label='SSAST')
axs[0].plot([i for i in range(1, results_mlp2_mean[:,2].size+1)],    results_mlp2_mean[:,2], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[0].plot([i for i in range(1, results_mlp2_meanmax[:,2].size+1)], results_mlp2_meanmax[:,2], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[0].plot([i for i in range(1, results_mlp2_max[:,2].size+1)],     results_mlp2_max[:,2], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[0].plot([i for i in range(1, results_mlp2_maxmax[:,2].size+1)],  results_mlp2_maxmax[:,2], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[0].legend(loc=(0.40, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[0].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[0].set_yticks(np.arange(0, np.max(results_mlp2_maxmax[:,0])+0.05, 0.001)) #, rotation=45)
axs[0].set_ylim(0.216, 0.234)
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('Average Precision with mlp_head 2 layers')
axs[0].grid(True, linestyle='-')
# axs[0].set_title('Accuracy with mlp_head 2 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 4 layers
axs[1].plot([i for i in range(1, results_ssast[:,2].size+1)],        results_ssast[:,2], 'o-', markersize=3, label='SSAST')
axs[1].plot([i for i in range(1, results_mlp4_mean[:,2].size+1)],    results_mlp4_mean[:,2], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[1].plot([i for i in range(1, results_mlp4_meanmax[:,2].size+1)], results_mlp4_meanmax[:,2], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[1].plot([i for i in range(1, results_mlp4_max[:,2].size+1)],     results_mlp4_max[:,2], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[1].plot([i for i in range(1, results_mlp4_maxmax[:,2].size+1)],  results_mlp4_maxmax[:,2], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[1].legend(loc=(0.40, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[1].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[1].set_yticks(np.arange(0, np.max(results_mlp4_maxmax[:,2])+0.05, 0.001)) #, rotation=45)
axs[1].set_ylim(0.212, 0.234)
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('Average Precision with mlp_head 4 layers')
axs[1].grid(True, linestyle='-')
# axs[1].set_title('Accuracy with mlp_head 4 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 6 layers
axs[2].plot([i for i in range(1, results_ssast[:,2].size+1)],        results_ssast[:,2], 'o-', markersize=3, label='SSAST')
axs[2].plot([i for i in range(1, results_mlp6_mean[:,2].size+1)],    results_mlp6_mean[:,2], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[2].plot([i for i in range(1, results_mlp6_meanmax[:,2].size+1)], results_mlp6_meanmax[:,2], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[2].plot([i for i in range(1, results_mlp6_max[:,2].size+1)],     results_mlp6_max[:,2], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[2].plot([i for i in range(1, results_mlp6_maxmax[:,2].size+1)],  results_mlp6_maxmax[:,2], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[2].legend(loc=(0.40, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[2].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[2].set_yticks(np.arange(0, np.max(results_mlp6_maxmax[:,2])+0.05, 0.001)) #, rotation=45)
axs[2].set_ylim(0.216, 0.234)
axs[2].set_xlabel('epoch')
axs[2].set_ylabel('Average Precision with mlp_head 6 layers')
axs[2].grid(True, linestyle='-')
# axs[2].set_title('Accuracy with mlp_head 6 layers\n', fontdict={'fontsize': 10}, loc='center', )


fig.savefig('Emotions_AP_num-layers_mlphead.png',dpi=300)

# %% [markdown]
# ### **subplots_AR**

# %%
fig, axs = plt.subplots(3,1,figsize=(6, 16))
# fig.suptitle('[Emotions] Average Recall with various number of layers at mlp_head') #, fontdict={'fontsize': 10}, loc='center', )


#mlp_head with 2 layers
axs[0].plot([i for i in range(1, results_ssast[:,3].size+1)],        results_ssast[:,3], 'o-', markersize=3, label='SSAST')
axs[0].plot([i for i in range(1, results_mlp2_mean[:,3].size+1)],    results_mlp2_mean[:,3], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[0].plot([i for i in range(1, results_mlp2_meanmax[:,3].size+1)], results_mlp2_meanmax[:,3], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[0].plot([i for i in range(1, results_mlp2_max[:,3].size+1)],     results_mlp2_max[:,3], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[0].plot([i for i in range(1, results_mlp2_maxmax[:,3].size+1)],  results_mlp2_maxmax[:,3], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[0].legend(loc=(0.40, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[0].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[0].set_yticks(np.arange(0.9, np.max(results_mlp2_maxmax[:,3])+0.05, 0.005)) #, rotation=45)
axs[0].set_ylim(0.970, 1.00)
axs[0].set_xlabel('epoch')
axs[0].set_ylabel('Average Recall with mlp_head 2 layers')
axs[0].grid(True, linestyle='-')
# axs[0].set_title('Accuracy with mlp_head 2 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 4 layers
axs[1].plot([i for i in range(1, results_ssast[:,3].size+1)],        results_ssast[:,3], 'o-', markersize=3, label='SSAST')
axs[1].plot([i for i in range(1, results_mlp4_mean[:,3].size+1)],    results_mlp4_mean[:,3], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[1].plot([i for i in range(1, results_mlp4_meanmax[:,3].size+1)], results_mlp4_meanmax[:,3], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[1].plot([i for i in range(1, results_mlp4_max[:,3].size+1)],     results_mlp4_max[:,3], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[1].plot([i for i in range(1, results_mlp4_maxmax[:,3].size+1)],  results_mlp4_maxmax[:,3], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[1].legend(loc=(0.40, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[1].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[1].set_yticks(np.arange(0.9, np.max(results_mlp4_maxmax[:,3])+0.05, 0.005)) #, rotation=45)
axs[1].set_ylim(0.970, 1.00)
axs[1].set_xlabel('epoch')
axs[1].set_ylabel('Average Recall with mlp_head 4 layers')
axs[1].grid(True, linestyle='-')
# axs[1].set_title('Accuracy with mlp_head 4 layers\n', fontdict={'fontsize': 10}, loc='center', )
# fig.savefig('[IurbanEvent]Accuracy_num-layers_mlphead.png',dpi=300)

#mlp_head with 6 layers
axs[2].plot([i for i in range(1, results_ssast[:,3].size+1)],        results_ssast[:,3], 'o-', markersize=3, label='SSAST')
axs[2].plot([i for i in range(1, results_mlp6_mean[:,3].size+1)],    results_mlp6_mean[:,3], 'o-', markersize=3, label='SSAST+Fusion mean pooling')
axs[2].plot([i for i in range(1, results_mlp6_meanmax[:,3].size+1)], results_mlp6_meanmax[:,3], 'o-', markersize=3, label='SSAST+Fusion mean+max pooling')
axs[2].plot([i for i in range(1, results_mlp6_max[:,3].size+1)],     results_mlp6_max[:,3], 'o-', markersize=3, label='SSAST+Fusion max pooling')
axs[2].plot([i for i in range(1, results_mlp6_maxmax[:,3].size+1)],  results_mlp6_maxmax[:,3], 'o-', markersize=3, label='SSAST+Fusion max+max pooling')
axs[2].legend(loc=(0.40, 0.01), fontsize=9) #(1.04, 0) :outer loc
# plt.xticks(rotation=45)
axs[2].set_xticks(np.arange(0, 50+1, 5)) #[Hyosun]results[:,0].size+1 해서 마지막 epoch 보이게
axs[2].set_yticks(np.arange(0.9, np.max(results_mlp6_maxmax[:,3])+0.05, 0.005)) #, rotation=45)
axs[2].set_ylim(0.970, 1.00)
axs[2].set_xlabel('epoch')
axs[2].set_ylabel('Average Recall with mlp_head 6 layers')
axs[2].grid(True, linestyle='-')
# axs[2].set_title('Accuracy with mlp_head 6 layers\n', fontdict={'fontsize': 10}, loc='center', )


fig.savefig('Emotions_AR_num-layers_mlphead.png',dpi=300)

# %%
        # if main_metrics == 'mAP':
        #     result[epoch-1, :] = [mAP, mAUC, average_precision, average_recall, d_prime(mAUC), loss_meter.avg, valid_loss, cum_mAP, cum_mAUC, optimizer.param_groups[0]['lr']]
        # else:
        #     result[epoch-1, :] = [acc, mAUC, average_precision, average_recall, d_prime(mAUC), loss_meter.avg, valid_loss, cum_acc, cum_mAUC, optimizer.param_groups[0]['lr']]
        # np.savetxt(exp_dir + '/result.csv', result, delimiter=',')
        # print('validation finished')

# %% [markdown]
# - result.csv에 들어가는 10 column들 순서:
#     - [acc, mAUC, average_precision, average_recall, d_prime(mAUC), loss_meter.avg, valid_loss, cum_acc, cum_mAUC, optimizer.param_groups[0]['lr']]
